# %% [markdown]
# 1.Write a program that print the numbers from 1 to 10 using loop

# %%
salary=int(input("enter your salary"))
service=int(input("enter your service years:")) 
if service>=5:
    bonus = salary*0.05
    print("Your bonus amount is:", bonus)
else:
    print("you are not eligible for a bonus yet.")
    print("net bonus amount:", bonus)
# Out:
# Running cells with 'Python 3.14.5' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/HAROON TRADERS/.local/bin/python3.14.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 2. Write a program to print even numbers from 1 to 10.

# %%
age=int(input("enter your age:"))
if age>=17:
    print("you are eligible for voting.")
else:
    print("you are not eligible for voting yet.")
# Out:
# Running cells with 'Python 3.14.5' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/HAROON TRADERS/.local/bin/python3.14.exe" -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# 3. Write a program that prints 'Happy Birthday!' five times on screen.

# %%
num=int(input("enter a number , and i will tell you whether it even or odd:"))
if num%2==0:
    print("the number is even.")
else:
    print("the number is odd.")

# %% [markdown]
# 4. Write a program that takes a number n as input from the user and generates the first
# n terms of the series formed by squaring the natural numbers.
# Sample output
# Enter a number: 6
# The first 6 terms of the series are:
# 1 4 9 16 25 36

# %%
num=int(input("enter a number and i will tell if it is divisible by 7:"))
if num%7==0:
    print("the number is divisible by 7.")
else:
    print("the number is not divisible by 7.")

# %% [markdown]
# 5. Write a program that prompts the user to input a number and prints its multiplication
# table.

# %%
num=int(input("enter a number:"))
if num%5==0:
    print("hello")
else:
    print("bye")

# %% [markdown]
# 6. Write a program that prompts the user to enter a number n, and then prints all the
# odd numbers between 1 and n.

# %%
length=int(input("enter the length of rectangle:"))
width=int(input("enter the width of rectangle:"))
if length==width:
    print("the rectangle is a square.")
else:
    print("the rectangle is not a square.")

# %% [markdown]
# 7. Write a Python program to print the numbers from 20 to 1 using a while loop.

# %%
num1=int(input("enter the 1st number:"))
num2=int(input("enter the 2nd number:"))
if num1>num2:
    print("the 1st number is greater than the 2nd number.")
else:
    print("the 2nd number is greater than the 1st number.")

# %% [markdown]
# 8. Write a program that prompts the user to enter a number n and prints all the
# numbers from 1 to n.

# %% [markdown]
# 9. Write a program that prompts the user to enter a number and repeats this process 5
# times. The program should accumulate the numbers entered and then display the final
# running total.
# - Sample Output:
# - Enter a number: 10
# - Enter a number: 15
# - Enter a number: 35
# - Enter a number: 40
# - Enter a number: 50
# - The final running total is: 150

# %%
grade=int(input("enter your grade:"))
if grade>=80:
    print("you got an A grade.")
elif grade>=60 and grade<80:
    print("you got a B grade.")
elif grade>=50 and grade<60:
    print("you got an C grade.")
elif grade>=45 and grade<50:
    print("you got an D grade.")
elif grade>=25 and grade<45:
    print("you got an E grade.")
else:
    print("you got an F grade.")

# %% [markdown]
# 10. Write a Python program that:
#
# 1- Creates a list named clean_countries containing the following countries:
# [Bangladesh
# India
# Pakistan
# China]
#
# 2- Repeatedly asks the user to enter a country name.
#
# 3- Checks whether the entered country exists in the clean_countries list.
#
# 4-If the country is found in the list:
#
# Display the message:
#
# <country_name> is in clean countries list
#
# Stop the program.
#
# 5-If the country is not found, keep asking the user to enter another country.

# %%
age=int(input("enter your age:"))
gender=input("enter your gender (M for male, F for female):")
martial_status=input("enter your martial status (Y for yes, N for no):")
if gender=="F":
    print("you can only work in urban areas.")
elif gender=="M" and age>=20 and age<=40:
    print("you can work anywhere.")
elif gender=="M" and age>=40 and age<=60:
    print("you can only work in urban areas.")
else:
    print("ERROR!")
